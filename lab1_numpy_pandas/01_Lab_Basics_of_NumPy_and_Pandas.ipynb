# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1. Matrix manipulation with NumPy
#
# ## Magic Square Check
#
# Practice matrix manipulation with NumPy by checking if a given matrix is a magic square. A magic square is a grid of numbers where the sums of the numbers in each row, each column, and both main diagonals are the same.
#
# Given a 3x3 Matrix:
#
# You are provided with the following 3x3 matrix:
#
#
# ```
# matrix = [
#   [8, 1, 6],
#   [3, 5, 7],
#   [4, 9, 2]
# ]
# ```
#
# Check if the Matrix is a Magic Square
#
# a. Calculate Row Sums:
#
# Calculate the sum of each row and store the results in a list.
#
# b. Calculate Column Sums:
#
# Calculate the sum of each column and store the results in a list.
#
# c. Calculate Diagonal Sums:
#
# Calculate the sum of the main diagonal (top-left to bottom-right) and the anti-diagonal (top-right to bottom-left).
#
# d. Check Equality:
#
# Verify if all the sums (row sums, column sums, and diagonal sums) are equal.
# If they are, print "The matrix is a magic square." Otherwise, print "The matrix is not a magic square."

# %%
matrix = [
    [8, 1, 6],
    [3, 5, 7],
    [4, 9, 2]
]

# Create numpy array with matrix
matrix = np.array(matrix)
matrix
# Out:
# array([[8, 1, 6],
#        [3, 5, 7],
#        [4, 9, 2]])

# %%
matrix = [
    [8, 1, 6],
    [3, 5, 7],
    [4, 9, 2]
]

# Create numpy array with matrix
matrix = np.array(matrix)

def magic_square_check(matrix):
    # Step 1: Calculate row sums
    row_sums = np.sum(matrix, axis=1)

    # Step 2: Calculate column sums
    column_sums = np.sum(matrix, axis=0)

    # Step 3: Calculate diagonal sums (hint: check the documentation for np.fliplr function)
    main_diagonal_sum = np.sum(np.diag(matrix))
    anti_diagonal_sum = np.sum(np.diag(np.fliplr(matrix)))

    # Step 4: Check if all sums are equal
    if (np.all(row_sums == row_sums[0]) and 
        np.all(column_sums == column_sums[0]) and 
        main_diagonal_sum == anti_diagonal_sum == row_sums[0]):
        return "The matrix is a magic square."
    else:
        return "The matrix is not a magic square."

magic_square_check(matrix)
# Out:
# 'The matrix is a magic square.'

# %% [markdown]
# Expected Output:
#
# The matrix is a magic square.

# %% [markdown]
# # Task 2: Introduction to Pandas Series

# %%
# You are given the sales data for a company over a week:

# Step 1: Create the Pandas Series
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sales = [1500, 2300, 1700, 2500, 3000, 4200, 3800]

# TODO: Create the Pandas Series with days as the index
sales_series = pd.Series(data=sales, index=days)

# Step 2: Explore the Series
print(sales_series)

# TODO: Print the number of elements in the Series

print(len(sales_series))
# Out:
# Monday       1500
# Tuesday      2300
# Wednesday    1700
# Thursday     2500
# Friday       3000
# Saturday     4200
# Sunday       3800
# dtype: int64
# 7

# %%
# Step 3: Access sales data in the Series
# TODO: Print the sales for "Wednesday" and "Saturday"
print(sales_series.loc[["Wednesday", "Saturday"]])
# Out:
# Wednesday    1700
# Saturday     4200
# dtype: int64

# %%
# TODO: Print the sales for the first and last days of the week
print(sales_series.iloc[[0, -1]])
# Out:
# Monday    1500
# Sunday    3800
# dtype: int64

# %%
# TODO: Print the sales from "Wednesday" to "Friday"
print(sales_series.loc['Wednesday':'Friday'])
# Out:
# Wednesday    1700
# Thursday     2500
# Friday       3000
# dtype: int64

# %%
# Step 4: Filtering and Conditional Selection
# TODO: Create a new Series with days having sales over $3,000
big_sales_series = sales_series[sales_series > 3000]
print(big_sales_series)
# Out:
# Saturday    4200
# Sunday      3800
# dtype: int64

# %%
# TODO: Check if any day had exactly $2,300 in sales
sales2300_series = sales_series[sales_series == 2300]
print(sales2300_series)
# Out:
# Tuesday    2300
# dtype: int64

# %%
# TODO: Check if all days had sales greater than $1,500
checksales_series = sales_series[sales_series > 1500].all()
print(checksales_series)
# Out:
# True

# %%
# Step 5: Basic Operations on Sales Data
# TODO: Apply a 10% increase and calculate new sales figures
increased_sales_series = sales_series * 1.1
print(increased_sales_series)
# Out:
# Monday       1650.0
# Tuesday      2530.0
# Wednesday    1870.0
# Thursday     2750.0
# Friday       3300.0
# Saturday     4620.0
# Sunday       4180.0
# dtype: float64

# %%
# TODO: Calculate sales after a 5% discount
discounted_sales_series = sales_series - sales_series * 0.05
print(discounted_sales_series)
# Out:
# Monday       1425.0
# Tuesday      2185.0
# Wednesday    1615.0
# Thursday     2375.0
# Friday       2850.0
# Saturday     3990.0
# Sunday       3610.0
# dtype: float64

# %%
# TODO: Calculate total, average, max, and min sales
total_sales = sales_series.sum()
average_sales = sales_series.mean()
max_sales = sales_series.max()
min_sales = sales_series.min()

print(f"Total sales: ${total_sales}")
print(f"Average sales: ${average_sales}")
print(f"Max sales: ${max_sales} on {sales_series.idxmax()}")
print(f"Min sales: ${min_sales} on {sales_series.idxmin()}")
# Out:
# Total sales: $19000
# Average sales: $2714.285714285714
# Max sales: $4200 on Saturday
# Min sales: $1500 on Monday

# %% [markdown]
# # Task 3. Practice with Pandas DataFrame

# %%
# Step 1: Create the Pandas DataFrame
data = {
    'Transaction ID': [1001, 1002, 1003, 1004, 1005, 1006],
    'Customer ID': [2001, 2002, 2001, 2003, 2002, 2004],
    'Product Category': ['Electronics', 'Clothing', 'Electronics', 'Groceries', 'Clothing', 'Electronics'],
    'Quantity': [1, 2, 1, 3, 1, 2],
    'Price per Unit': [300, 50, 300, 20, 50, 300],
    'Costs per Unit': [200, 50, 250, 20, 10, 150],
    'Transaction Date': ['2024-08-01', '2024-08-02', '2024-08-02', '2024-08-03', '2024-08-03', '2024-08-04']
}
transactions_df = pd.DataFrame(data=data)
transactions_df
# Out:
#    Transaction ID  Customer ID Product Category  Quantity  Price per Unit  \
# 0            1001         2001      Electronics         1             300
# 1            1002         2002         Clothing         2              50
# 2            1003         2001      Electronics         1             300
# 3            1004         2003        Groceries         3              20
# 4            1005         2002         Clothing         1              50
# 5            1006         2004      Electronics         2             300
#
#    Costs per Unit Transaction Date
# 0             200       2024-08-01
# 1              50       2024-08-02
# 2             250       2024-08-02
# 3              20       2024-08-03
# 4              10       2024-08-03
# 5             150       2024-08-04

# %%
# TODO: Create the DataFrame
transactions_df = pd.DataFrame(data=data)
transactions_df
# Out:
#    Transaction ID  Customer ID Product Category  Quantity  Price per Unit  \
# 0            1001         2001      Electronics         1             300
# 1            1002         2002         Clothing         2              50
# 2            1003         2001      Electronics         1             300
# 3            1004         2003        Groceries         3              20
# 4            1005         2002         Clothing         1              50
# 5            1006         2004      Electronics         2             300
#
#    Costs per Unit Transaction Date
# 0             200       2024-08-01
# 1              50       2024-08-02
# 2             250       2024-08-02
# 3              20       2024-08-03
# 4              10       2024-08-03
# 5             150       2024-08-04

# %%
# TODO: Convert 'Transaction Date' to datetime format
transactions_df['Transaction Date'] = pd.to_datetime(transactions_df['Transaction Date'])

# %%
# Step 2: Calculate Key Metrics
# TODO: Calculate 'Total Revenue' for each transaction
transactions_df['Total Revenue'] = transactions_df['Quantity'] * transactions_df['Price per Unit']
transactions_df
# Out:
#    Transaction ID  Customer ID Product Category  Quantity  Price per Unit  \
# 0            1001         2001      Electronics         1             300
# 1            1002         2002         Clothing         2              50
# 2            1003         2001      Electronics         1             300
# 3            1004         2003        Groceries         3              20
# 4            1005         2002         Clothing         1              50
# 5            1006         2004      Electronics         2             300
#
#    Costs per Unit Transaction Date  Total Revenue
# 0             200       2024-08-01            300
# 1              50       2024-08-02            100
# 2             250       2024-08-02            300
# 3              20       2024-08-03             60
# 4              10       2024-08-03             50
# 5             150       2024-08-04            600

# %%
# TODO: Calculate Customer Lifetime Value (CLV)
# CLV = total revenue by the customer
# Return DataFrame with columns: ['Customer ID', 'Customer Lifetime Value']
clv_df = transactions_df.groupby('Customer ID')['Total Revenue'].sum().reset_index()
clv_df.rename(columns={'Total Revenue': 'Customer Lifetime Value'}, inplace=True)
clv_df
# Out:
#    Customer ID  Customer Lifetime Value
# 0         2001                      600
# 1         2002                      150
# 2         2003                       60
# 3         2004                      600

# %%
transactions_df['Total Revenue'] = transactions_df['Quantity'] * transactions_df['Price per Unit']
# TODO: Analyze Product Category Popularity
# Calculate the Quantity and Total Revenue by the Product Category

product_category_stats = transactions_df.groupby('Product Category')[['Total Revenue', 'Quantity']].sum().reset_index()
product_category_stats
# Out:
#   Product Category  Total Revenue  Quantity
# 0         Clothing            150         3
# 1      Electronics           1200         4
# 2        Groceries             60         3

# %%
# Step 3: Customer Segmentation
# TODO: Segment Customers Based on Revenue:

# Create a new column in clv_df to categorize customers into three segments:
# High Value (CLV > $500)
# Medium Value ($200 < CLV <= $500)
# Low Value (CLV <= $200)

# %%
# Step 3: Customer Segmentation
# TODO: Segment customers based on CLV

def det_category(clv):
    if clv > 500:
        return 'High Value'
    elif 200 < clv <= 500:
        return 'Medium Value'
    else:
        return 'Low Value' 
        
clv_df['Segment'] = clv_df['Customer Lifetime Value'].apply(det_category) 
clv_df
# Out:
#    Customer ID  Customer Lifetime Value     Segment
# 0         2001                      600  High Value
# 1         2002                      150   Low Value
# 2         2003                       60   Low Value
# 3         2004                      600  High Value

# %%
# # TODO: Count the number of customers in each segment
segment_counts = clv_df.groupby('Segment')['Customer ID'].count().reset_index()
segment_counts.rename(columns={'Customer ID': 'The number of customers in each segment'}, inplace=True)

segment_counts
# Out:
#       Segment  The number of customers in each segment
# 0  High Value                                        2
# 1   Low Value                                        2

# %%
# Step 4: Sales Trends
# TODO: Calculate daily revenue
daily_revenue = transactions_df.groupby('Transaction Date')['Total Revenue'].sum()

# Visualize daily revenue trend
daily_revenue.plot(kind='line', title='Daily Revenue Trend')
plt.show()

# %% [markdown]
# # Task 4. Practice with real dataset

# %%
# Step 1: Load and Explore the Data
# TODO: Load the Titanic dataset (location: data/raw)
path = 'C:\\Users\\Дмитро\\pythonlibs\\Python4DS\\data\\raw\\titanic.csv'
titanic_df = pd.read_csv(path)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# TODO: Display the first few rows
titanic_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# TODO: Check for missing values
titanic_df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
# TODO: Drop rows with missing Age or Embarked values
titanic_df = titanic_df.dropna(subset=['Age','Embarked'], axis=0)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [712 rows x 12 columns]

# %%
# Step 2: Calculate Survival Rates by Class and Gender
# TODO: Calculate survival rate by class
survival_by_class = titanic_df.groupby('Pclass')['Survived'].mean().reset_index()
print("\n", round((survival_by_class * 100), 2).astype(str) + ' %')

# TODO: Calculate survival rate by gender
survival_by_gender = titanic_df.groupby('Sex')['Survived'].mean().reset_index()
print("\n", round((survival_by_class * 100), 2).astype(str) + ' %')

# TODO: Calculate combined survival rate by class and gender
combined_survival =  titanic_df.groupby(['Pclass', 'Sex'])['Survived'].mean()
print(f"\n {round(combined_survival * 100, 2)} %")
# Out:
#    Pclass Survived
# 0  100 %  65.22 %
# 1  200 %  47.98 %
# 2  300 %  23.94 %
#
#    Pclass Survived
# 0  100 %  65.22 %
# 1  200 %  47.98 %
# 2  300 %  23.94 %
#
#  Pclass  Sex
# 1       female    96.39
#         male      39.60
# 2       female    91.89
#         male      15.15
# 3       female    46.08
#         male      15.02
# Name: Survived, dtype: float64 %

# %%
# Step 3: Analyze the Impact of Age on Survival
# TODO: Create age groups (use pd.cut function)
bins = [0, 12, 19, 59, 120]
labels = ['Child', 'Teenager', 'Adult', 'Senior']
titanic_df['AgeGroup'] = pd.cut(titanic_df['Age'], bins=bins, labels=labels)
#print(titanic_df['AgeGroup'])

# TODO: Calculate survival rate by age group
survival_by_age_group = titanic_df.groupby('AgeGroup')['Survived'].mean()
print('\n', survival_by_age_group * 100)
# Out:
#  AgeGroup
# Child       57.971014
# Teenager    41.052632
# Adult       38.814532
# Senior      24.000000
# Name: Survived, dtype: float64
# C:\Users\Дмитро\AppData\Local\Temp\ipykernel_1328\1151312795.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_df['AgeGroup'] = pd.cut(titanic_df['Age'], bins=bins, labels=labels)
# C:\Users\Дмитро\AppData\Local\Temp\ipykernel_1328\1151312795.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_by_age_group = titanic_df.groupby('AgeGroup')['Survived'].mean()

# %%
# TODO: Visualize age vs. survival
survival_by_age_group.plot(kind='bar', title='Survival Rate by Age Group')
plt.show()
